# %% [markdown]
# # Coconut classification with TensorFlow Lite Model Maker with TensorFlow 2.0
#
# References :
#
# [1]https://www.tensorflow.org/lite/tutorials/model_maker_image_classification

# %%
#@title Licensed under the Apache License, Version 2.0 (the "License");
# you may not use this file except in compliance with the License.
# You may obtain a copy of the License at
#
# https://www.apache.org/licenses/LICENSE-2.0
#
# Unless required by applicable law or agreed to in writing, software
# distributed under the License is distributed on an "AS IS" BASIS,
# WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# See the License for the specific language governing permissions and
# limitations under the License.

# %% [markdown]
# Model Maker library simplifies the process of adapting and converting a TensorFlow neural-network model to particular input data when deploying this model for on-device ML applications.

# %% [markdown]
# ## Prerequisites
#
# install serveral required packages, including Model Maker package that in github [repo](https://github.com/tensorflow/examples/tree/master/tensorflow_examples/lite/model_maker).

# %%
# !pip install -q tflite-model-maker
# Out:
#      |████████████████████████████████| 616 kB 8.6 MB/s
#      |████████████████████████████████| 77 kB 4.8 MB/s
#      |████████████████████████████████| 3.4 MB 36.3 MB/s
#      |████████████████████████████████| 840 kB 49.6 MB/s
#      |████████████████████████████████| 1.2 MB 48.3 MB/s
#      |████████████████████████████████| 87 kB 6.4 MB/s
#      |████████████████████████████████| 1.1 MB 31.2 MB/s
#      |████████████████████████████████| 6.4 MB 44.8 MB/s
#      |████████████████████████████████| 120 kB 52.0 MB/s
#      |████████████████████████████████| 1.1 MB 69.4 MB/s
#      |████████████████████████████████| 596 kB 57.8 MB/s
#      |████████████████████████████████| 237 kB 56.7 MB/s
#      |████████████████████████████████| 25.3 MB 1.4 MB/s
#      |████████████████████████████████| 352 kB 70.9 MB/s
#      |████████████████████████████████| 47.8 MB 45 kB/s
#      |████████████████████████████████| 99 kB 8.0 MB/s
#      |████████████████████████████████| 462 kB 42.9 MB/s
# ...

# %% [markdown]
# Import the required packages.

# %%
from tflite_model_maker import image_classifier
from tflite_model_maker.image_classifier import DataLoader

import tensorflow as tf
assert tf.__version__.startswith('2')

import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Get the data path
#
# Let's get the images

# %%
image_path = '/content/drive/MyDrive/coconut_dataset/train'

# %% [markdown]
# ### 1.   Load input data specific to an on-device ML app. Split it to training data and testing data.

# %%
data = DataLoader.from_folder(image_path)
train_data, rest_data = data.split(0.8)
validation_data, test_data = rest_data.split(0.5)
# Out:
# INFO:tensorflow:Load image with size: 876, num_label: 2, labels: mature, tender.

# %%
plt.figure(figsize=(10,10))
for i, (image, label) in enumerate(data.gen_dataset().unbatch().take(25)):
  plt.subplot(5,5,i+1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.imshow(image.numpy(), cmap=plt.cm.gray)
  plt.xlabel(data.index_to_label[label.numpy()])
plt.show()

# %% [markdown]
# ### 2. Customize the TensorFlow model.
# Create a custom image classifier model based on the loaded data. Here ResNet50 will be used.

# %%
model = image_classifier.Resnet50Spec(
   uri='https://tfhub.dev/google/imagenet/resnet_v2_50/feature_vector/4',
    compat_tf_versions=2,
    input_image_shape=None,
    name='resnet_50'

)
model = image_classifier.create(train_data, model_spec = 'resnet_50', validation_data=validation_data, epochs = 4)
# Out:
# INFO:tensorflow:Retraining the models...
# INFO:tensorflow:Retraining the models...
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  hub_keras_layer_v1v2_1 (Hub  (None, 2048)             23564800
#  KerasLayerV1V2)
#
#  dropout_1 (Dropout)         (None, 2048)              0
#
#  dense_1 (Dense)             (None, 2)                 4098
#
# ...
# Total params: 23,568,898
# Trainable params: 4,098
# Non-trainable params: 23,564,800
# _________________________________________________________________
# None
# Epoch 1/4
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 21/21 [==============================] - 640s 29s/step - loss: 0.5413 - accuracy: 0.8036 - val_loss: 0.4343 - val_accuracy: 0.9205
# Epoch 2/4
# ...

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  hub_keras_layer_v1v2_1 (Hub  (None, 2048)             23564800
#  KerasLayerV1V2)
#
#  dropout_1 (Dropout)         (None, 2048)              0
#
#  dense_1 (Dense)             (None, 2)                 4098
#
# ...
# Total params: 23,568,898
# Trainable params: 4,098
# Non-trainable params: 23,564,800
# _________________________________________________________________

# %% [markdown]
# ### 3: Evaluate the Customized Model

# %%
loss, accuracy = model.evaluate(test_data)
# Out:
# 3/3 [==============================] - 144s 16s/step - loss: 0.3105 - accuracy: 0.9318

# %% [markdown]
# ## Inference

# %%
# A helper function that returns 'red'/'black' depending on if its two input
# parameter matches or not.
def get_label_color(val1, val2):
  if val1 == val2:
    return 'black'
  else:
    return 'red'

# Then plot 100 test images and their predicted labels.
# If a prediction result is different from the label provided label in "test"
# dataset, we will highlight it in red color.
plt.figure(figsize=(20, 20))
predicts = model.predict_top_k(test_data)
for i, (image, label) in enumerate(test_data.gen_dataset().unbatch().take(100)):
  ax = plt.subplot(10, 10, i+1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.imshow(image.numpy(), cmap=plt.cm.gray)

  predict_label = predicts[i][0][0]
  color = get_label_color(predict_label,
                          test_data.index_to_label[label.numpy()])
  ax.xaxis.label.set_color(color)
  plt.xlabel('Predicted: %s' % predict_label)
plt.show()

# %%
test_path = '/content/drive/MyDrive/coconut_dataset/test'
test_data1 = DataLoader.from_folder(test_path)
loss, accuracy = model.evaluate(test_data1)
# Out:
# INFO:tensorflow:Load image with size: 70, num_label: 2, labels: mature, tender.
# INFO:tensorflow:Load image with size: 70, num_label: 2, labels: mature, tender.
# 3/3 [==============================] - 58s 13s/step - loss: 0.5077 - accuracy: 0.8714

# %% [markdown]
# ### 4.  Export to TensorFlow Lite model.

# %%
model.export(export_dir='/content/drive/MyDrive/SavedModels/12_Apr_ResNet50_80_10_10_Acc93')
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpcvfjva_i/assets
# INFO:tensorflow:Assets written to: /tmp/tmpcvfjva_i/assets
# /usr/local/lib/python3.7/dist-packages/tensorflow/lite/python/convert.py:746: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn("Statistics for quantized inputs were expected, but not "
# INFO:tensorflow:Label file is inside the TFLite model with metadata.
# INFO:tensorflow:Label file is inside the TFLite model with metadata.
# INFO:tensorflow:Saving labels in /tmp/tmpr3n7m93x/labels.txt
# INFO:tensorflow:Saving labels in /tmp/tmpr3n7m93x/labels.txt
# INFO:tensorflow:TensorFlow Lite model exported successfully: /content/drive/MyDrive/SavedModels/12_Apr_ResNet50_80_10_10_Acc93/model.tflite
# INFO:tensorflow:TensorFlow Lite model exported successfully: /content/drive/MyDrive/SavedModels/12_Apr_ResNet50_80_10_10_Acc93/model.tflite

# %% [markdown]
# 5. Download the trained model

# %%
from google.colab import files
files.download('/content/drive/MyDrive/SavedModels/12_Apr_ResNet50_80_10_10_Acc93/model.tflite')
